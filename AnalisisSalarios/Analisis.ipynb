# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cargando los datos

# %%
df = pd.read_csv('./ds_salaries.csv')

# %% [markdown]
# ## Primeros Analisis

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.rename_axis('Unnamed: 0').reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Andres\workspace\dataScienceGithub\proyectos\AnalisisSalarios\Analisis.ipynb Celda 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/dataScienceGithub/proyectos/AnalisisSalarios/Analisis.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df.rename_axis('Unnamed: 0').reset_index()
#
# File c:\Users\Andres\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
des = df.describe()
des
# Out:
#          work_year        salary  salary_in_usd  remote_ratio  Salario en CLP  \
# count   607.000000  6.070000e+02     607.000000     607.00000    6.070000e+02
# mean   2021.405272  3.240001e+05  112297.869852      70.92257    1.030333e+08
# std       0.692133  1.544357e+06   70957.259411      40.70913    6.510329e+07
# min    2020.000000  4.000000e+03    2859.000000       0.00000    2.623132e+06
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000    5.755110e+07
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000    9.319048e+07
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000    1.376250e+08
# max    2022.000000  3.040000e+07  600000.000000     100.00000    5.505000e+08
#
#        Salario en CLP Mensual
# count            6.070000e+02
# mean             8.586108e+06
# std              5.425274e+06
# min              2.185944e+05
# 25%              4.795925e+06
# 50%              7.765873e+06
# 75%              1.146875e+07
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
salary_mean = df['salary_in_usd'].mean()

# %%
salary_mean
# Out:
# 112297.86985172982

# %%
df['salary_in_usd'].hist()
# Out:
# <AxesSubplot:>

# %%
df[df['salary_in_usd'] > salary_mean]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 1             1       2020               SE              FT
# 4             4       2020               SE              FT
# 6             6       2020               SE              FT
# 8             8       2020               MI              FT
# 9             9       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist  260000             USD         260000
# 4     Machine Learning Engineer  150000             USD         150000
# ...

# %%
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)

# %%
df
# Out:
#       Id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
df.index = df['Id']

# %%
df.drop('Id', axis=1, inplace=True)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# Id
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df['experience_level'].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
df[(df['job_title'] == 'Data Scientist') | (df['job_title'] == 'Data Analyst')]
# Out:
#      work_year experience_level employment_type       job_title    salary  \
# Id
# 0         2020               MI              FT  Data Scientist     70000
# 5         2020               EN              FT    Data Analyst     72000
# 7         2020               MI              FT  Data Scientist  11000000
# 10        2020               EN              FT  Data Scientist     45000
# 11        2020               MI              FT  Data Scientist   3000000
# ..         ...              ...             ...             ...       ...
# 599       2022               MI              FT  Data Scientist    130000
# 600       2022               EN              FT    Data Analyst     67000
# 601       2022               EN              FT    Data Analyst     52000
# 604       2022               SE              FT    Data Analyst    129000
# 605       2022               SE              FT    Data Analyst    150000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# Id
# ...

# %%
dataScience_Inf = df[(df['job_title'] == 'Data Scientist')]
dataAnalist_Inf = df[(df['job_title'] == 'Data Analyst')]

# %%
def salarioAclp(df):
    df['Salario en CLP'] = df['salary_in_usd'] * 917.5
    return df
def salarioAclp_Mensual(df):
    
    df['Salario en CLP Mensual'] = round(df['Salario en CLP'] / 12, 1)
salarioAclp(dataScience_Inf)
salarioAclp(dataAnalist_Inf)
# Out:
# C:\Users\Andres\AppData\Local\Temp\ipykernel_13440\707338718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salario en CLP'] = df['salary_in_usd'] * 917.5
# C:\Users\Andres\AppData\Local\Temp\ipykernel_13440\707338718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salario en CLP'] = df['salary_in_usd'] * 917.5
#      work_year experience_level employment_type     job_title  salary  \
# Id
# 5         2020               EN              FT  Data Analyst   72000
# ...

# %%
salarioAclp(df)
# Out:
#      work_year experience_level employment_type                   job_title  \
# Id
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
salarioAclp_Mensual(df)
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# Id
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df[df['experience_level'] == 'SE'].sort_values(by='Salario en CLP Mensual', ascending=False)
# Out:
#      work_year experience_level employment_type                  job_title  \
# Id
# 63        2020               SE              FT             Data Scientist
# 523       2022               SE              FT        Data Analytics Lead
# 519       2022               SE              FT     Applied Data Scientist
# 93        2021               SE              FT         Lead Data Engineer
# 534       2022               SE              FT             Data Architect
# ..         ...              ...             ...                        ...
# 579       2022               SE              FT              Data Engineer
# 197       2021               SE              FT  Machine Learning Engineer
# 133       2021               SE              FT   Computer Vision Engineer
# 278       2021               SE              FT             Data Scientist
# 271       2021               SE              FT   Computer Vision Engineer
#
# ...

# %%
plt.figure(figsize=(20, 6))
df["company_location"].value_counts().plot(kind="bar", )
# Out:
# <AxesSubplot:>

# %%
sueldosPromporubCLP = []
for i in df['company_location'].unique():
    sueldosPromporub.append(round(df[df['company_location'] == i]['Salario en CLP Mensual'].mean(), 1))
print(sueldosPromporub)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Andres\workspace\dataScienceGithub\proyectos\AnalisisSalarios\Analisis.ipynb Celda 25 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/dataScienceGithub/proyectos/AnalisisSalarios/Analisis.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> sueldosPromporubCLP = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/dataScienceGithub/proyectos/AnalisisSalarios/Analisis.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> for i in df['company_location'].unique():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/dataScienceGithub/proyectos/AnalisisSalarios/Analisis.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     sueldosPromporub.append(round(df[df['company_location'] == i]['Salario en CLP Mensual'].mean(), 1))
# ...

# %%
plt.figure(figsize=(20, 6))
plt.bar(df['company_location'].unique(), sueldosPromporub)
# Out:
# <BarContainer object of 50 artists>

# %%
df['company_location'].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'CN',
#        'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'ES', 'PT', 'DK', 'IT',
#        'HR', 'LU', 'PL', 'SG', 'RO', 'IQ', 'BR', 'BE', 'UA', 'IL', 'RU',
#        'MT', 'CL', 'IR', 'CO', 'MD', 'KE', 'SI', 'CH', 'VN', 'AS', 'TR',
#        'CZ', 'DZ', 'EE', 'MY', 'AU', 'IE'], dtype=object)

# %%
print(df[df['company_location'] == 'RU']['Salario en CLP Mensual'].mean())
print(df[df['company_location'] == 'US']['Salario en CLP Mensual'].mean())
# Out:
# 12042187.5
# 11014225.237746479

# %%
plt.figure(figsize=(20, 6))
sueldosPromporubUSD = df.groupby('company_location')['salary_in_usd'].mean().plot(kind='bar')
# print(sueldosPromporubUSD)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Andres\workspace\cursoDataScience\proyectos\Analisis.ipynb Celda 28 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/cursoDataScience/proyectos/Analisis.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(20, 6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andres/workspace/cursoDataScience/proyectos/Analisis.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> sueldosPromporubUSD = df.groupby('company_location').unique()['salary_in_usd'].mean().plot(kind='bar')
#
# File c:\Users\Andres\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
# ...

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# Id
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df.groupby('company_size')['salary_in_usd'].mean()
# Out:
# company_size
# L    119242.994949
# M    116905.466258
# S     77632.674699
# Name: salary_in_usd, dtype: float64

# %%
tamañoEmpresa
